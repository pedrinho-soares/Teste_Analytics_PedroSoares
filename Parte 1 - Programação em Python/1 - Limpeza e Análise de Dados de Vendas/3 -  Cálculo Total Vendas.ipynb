# %% [markdown]
# #### Parte 3 de 4 do Script em Python

# %% [markdown]
# #### Nesta terceira parte irei realizar as seguintes análises utilizando o dataset limpo:
#
# ■    Calcular o total de vendas (Quantidade * Preço) por produto.
#
# ■    Identifique o produto com o maior número de vendas totais.

# %% [markdown]
# #### Vamos importar as bibliotecas necessárias pra esse cálculo. Utilizarei o Pandas porque é o suficiente para cálculos simples e agrupamentos.

# %%
import pandas as pd

# %% [markdown]
# #### Chamando minha tabela limpa para trabalharmos nela

# %%
df= pd.read_csv('data_clean.csv')
df = df.drop(columns=['Unnamed: 0']).reset_index(drop=True)

# %% [markdown]
# #### Criando uma coluna nova "Preço Total" e calculando QUANTIDADE VEZES PREÇO

# %%
df['Total_vendas'] = df['Quantidade'] * df['Preço']

# %% [markdown]
# #### Chamei pra visualizar as 15 linhas só pra ter uma ideia de como ficou e deu certo

# %%
df.head(15)
# Out:
#      ID        Data  Produto Tamanho  Preço  Quantidade          Categoria  \
# 0   558  2023-05-26  Sorvete   700ml     20           1            Natural
# 1   160  2023-08-09  Sorvete   200ml     10           1  Batido com frutas
# 2   903  2023-01-06     Acai   500ml     16           2            Natural
# 3   367  2023-11-27  Sorvete   300ml     13           2  Batido com frutas
# 4    76  2023-07-07     Acai   400ml     14           1  Batido com frutas
# 5   927  2023-05-25     Acai   500ml     16           2  Batido com frutas
# 6   566  2023-06-04  Sorvete   200ml     10           2  Batido com frutas
# 7   264  2023-04-09  Sorvete   300ml     13           2  Batido com frutas
# 8   738  2023-09-19     Acai   400ml     14           2            Natural
# 9   250  2023-05-31     Acai   200ml     10           1            Natural
# 10  962  2023-02-18  Sorvete   200ml     10           2            Natural
# 11  790  2023-02-04  Sorvete   400ml     14           1            Natural
# 12  798  2023-01-09     Acai   500ml     16           1            Natural
# 13  864  2023-01-12  Sorvete   200ml     10           2            Natural
# 14  590  2023-07-09     Acai   200ml     10           2            Natural
#
#    Forma de Pagamento      Hora  Valor Total  Total_vendas
# 0              debito  17:42:00           20            20
# 1                 pix  12:07:00           10            10
# 2                 pix  19:47:00           32            32
# 3                 pix  10:30:00           26            26
# 4              debito  18:15:00           14            14
# 5                 pix  10:48:00           32            32
# 6                 pix  18:34:00           20            20
# 7              debito  12:35:00           26            26
# 8                 pix  17:07:00           28            28
# 9             credito  12:28:00           10            10
# 10             debito  18:53:00           20            20
# 11                pix  13:24:00           14            14
# 12             debito  10:58:00           16            16
# 13             debito  14:40:00           20            20
# 14                pix  17:16:00           20            20

# %%
#Calculando a média de meus produtos só pra ter uma ideia do preço. (por curiosidade mesmo)
df["Preço"].mean()
# Out:
# 14.87906976744186

# %% [markdown]
# #### Vamos identificar o produto com maior número de vendas agora calculando o total de vendas vezes produto.

# %%
mais_vendido = df.groupby('Produto')['Total_vendas'].sum()

# Exibindo o resultado
print(mais_vendido)
# Out:
# Produto
# Acai       4448
# Sorvete    5215
# Name: Total_vendas, dtype: int64

# %% [markdown]
# #### O SORVETE foi o produto com o maior número de vendas

# %% [markdown]
# ##                                                  Parte 4 de 4 do Script - Análise Exploratória de Dados de Vendas

# %% [markdown]
# Com o mesmo dataset simulado da tarefa anterior, vamos criar visualizações/gráficos e com eles devemos:
#
# ■    Criar um gráfico de linha mostrando a tendência de vendas ao longo do tempo, analisando os dados mensalmente.
#
# ■    Identificar e descrever pelo menos dois padrões ou insights interessantes que observei nos dados.

# %% [markdown]
# #### Vou começar importando as bibliotecas necessárias
# * Pandas: Para manipulação e análise dos dados.
# * Matplotlib: Para criar visualizações básicas, como gráficos de linha.

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
#visualizando que tipo de dados são os meus pois preciso converter alguns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  430 non-null    int64
#  1   Data                430 non-null    object
#  2   Produto             430 non-null    object
#  3   Tamanho             430 non-null    object
#  4   Preço               430 non-null    int64
#  5   Quantidade          430 non-null    int64
#  6   Categoria           430 non-null    object
#  7   Forma de Pagamento  430 non-null    object
#  8   Hora                430 non-null    object
#  9   Valor Total         430 non-null    int64
#  10  Total_vendas        430 non-null    int64
# dtypes: int64(5), object(6)
# memory usage: 37.1+ KB

# %% [markdown]
# #### Vou converter a coluna 'Data' para datetime, ela está como 'object'. O formato datetime permite o Pandas reconhecer esses valores 'Data' como datas, facilitando a manipulação, análise e visualização futuramente.

# %%
df['Data'] = pd.to_datetime(df['Data'])

# %%
df['ano_mes'] = df['Data'].dt.to_period('M')
print()

# %%
vendas_mensais = df.groupby('ano_mes')['Total_vendas'].sum()

# %%
df.head(15)
# Out:
#      ID       Data  Produto Tamanho  Preço  Quantidade          Categoria  \
# 0   558 2023-05-26  Sorvete   700ml     20           1            Natural
# 1   160 2023-08-09  Sorvete   200ml     10           1  Batido com frutas
# 2   903 2023-01-06     Acai   500ml     16           2            Natural
# 3   367 2023-11-27  Sorvete   300ml     13           2  Batido com frutas
# 4    76 2023-07-07     Acai   400ml     14           1  Batido com frutas
# 5   927 2023-05-25     Acai   500ml     16           2  Batido com frutas
# 6   566 2023-06-04  Sorvete   200ml     10           2  Batido com frutas
# 7   264 2023-04-09  Sorvete   300ml     13           2  Batido com frutas
# 8   738 2023-09-19     Acai   400ml     14           2            Natural
# 9   250 2023-05-31     Acai   200ml     10           1            Natural
# 10  962 2023-02-18  Sorvete   200ml     10           2            Natural
# 11  790 2023-02-04  Sorvete   400ml     14           1            Natural
# 12  798 2023-01-09     Acai   500ml     16           1            Natural
# 13  864 2023-01-12  Sorvete   200ml     10           2            Natural
# 14  590 2023-07-09     Acai   200ml     10           2            Natural
#
#    Forma de Pagamento      Hora  Valor Total  Total_vendas  ano_mes
# 0              debito  17:42:00           20            20  2023-05
# 1                 pix  12:07:00           10            10  2023-08
# 2                 pix  19:47:00           32            32  2023-01
# 3                 pix  10:30:00           26            26  2023-11
# 4              debito  18:15:00           14            14  2023-07
# 5                 pix  10:48:00           32            32  2023-05
# 6                 pix  18:34:00           20            20  2023-06
# 7              debito  12:35:00           26            26  2023-04
# 8                 pix  17:07:00           28            28  2023-09
# 9             credito  12:28:00           10            10  2023-05
# 10             debito  18:53:00           20            20  2023-02
# 11                pix  13:24:00           14            14  2023-02
# 12             debito  10:58:00           16            16  2023-01
# 13             debito  14:40:00           20            20  2023-01
# 14                pix  17:16:00           20            20  2023-07

# %% [markdown]
# #### Irei trazer o gráfico de linhas para analisarmos tendências

# %% [markdown]
# #### Vamos dar um nome a este gráfico, ele se chamará "Gráfico A1". Isso será útil para localizar a explicação dele em nossa documentação.

# %%
vendas_mensais.plot(kind='line', marker='p', figsize=(15, 6))
plt.title('Tendência de Vendas Mensal - Gráfico A1')
plt.xlabel('Mês e Ano')
plt.ylabel('Total de Vendas')
#vou adicionar grades ao fundo para melhor visualização para assim que olhar já ter ideia da tendência
plt.grid(True)
plt.show()

#GRAFICO A1 PLOTADO

# %% [markdown]
# #### Vimos que as vendas tiveram um pico grande, talvez de "8 pra 80". Ao dar o pico máximo, elas diminuem depois de forma gradativa, de 1 a 2 meses pra dar a baixa dela. Entre agosto e novembro elas mantém um padrão.

# %% [markdown]
# #### Vamos fazer um gráfico para ver as vendas de sorvete e açai no mesmo grafico para vermos quem vendeu mais em cada mês.

# %%
# Filtrando os dados por produto
df_acai = df[df['Produto'] == 'Acai']
df_sorvete = df[df['Produto'] == 'Sorvete']

# Extraindo o mês de 'ano_mes'
df_acai['Mês'] = df_acai['ano_mes'].dt.month
df_sorvete['Mês'] = df_sorvete['ano_mes'].dt.month

# Agrupando as vendas por mês
vendas_acai_por_mes = df_acai.groupby('Mês')['Total_vendas'].sum()
vendas_sorvete_por_mes = df_sorvete.groupby('Mês')['Total_vendas'].sum()

# Definindo os meses de 1 a 12
meses = range(1, 13)

# Plotando os dados
plt.figure(figsize=(10, 6))
plt.plot(meses, vendas_acai_por_mes.reindex(meses, fill_value=0), marker='p', label='Açaí')
plt.plot(meses, vendas_sorvete_por_mes.reindex(meses, fill_value=0), marker='o', label='Sorvete')

# Configurações do gráfico
plt.title('Comparação de Vendas por Mês - Açaí vs Sorvete - Gráfico a2')
plt.xlabel('Mês')
plt.ylabel('Total de Vendas')
plt.xticks(meses)
plt.legend()
plt.grid()
plt.show()

#GRAFICO A2 PLOTADO
# Out:
# C:\Users\Pedro Soares\AppData\Local\Temp\ipykernel_12660\290602824.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acai['Mês'] = df_acai['ano_mes'].dt.month
# C:\Users\Pedro Soares\AppData\Local\Temp\ipykernel_12660\290602824.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sorvete['Mês'] = df_sorvete['ano_mes'].dt.month

# %% [markdown]
# ## Padrões, Tendências e Insights encontrados:
# * Sazonalidade:
#     * Há uma clara indicação de sazonalidade nas vendas tanto de açaí quanto de sorvete. As vendas tendem a aumentar em determinados meses e diminuir em outros.
#     * Pico de Vendas: As vendas de ambos os produtos alcançam um pico nos meses mais quentes do ano e em epocas de férias escolares (janeiro, fevereiro, junho e julho) (considerando o contexto de Cabo Frio).
#
# ## Hipóteses:
# * Clima e Local:
#     * A principal hipótese é que o clima tem uma influência forte nas vendas de produtos gelados, com os meses mais quentes do ano impulsionando a procura por produtos gelados como açaí e sorvete.
#     * Fatores Culturais: Pode haver fatores culturais ou hábitos locais que influenciam o consumo de açaí e sorvete em determinados períodos do ano. Por exemplo, os alunos do turno da manhã de uma escola ao sair da escola podem ter o costume de juntar um grupo para tomar açai. (No contexto de Cabo Frio, uma parte grande dos alunos tem esse costume e preferem açai)
#
# ## Insight:
# * Combinação de clima e fatores culturais:
#     * Em períodos onde o clima quente coincide com festividades ou férias escolares, o impacto nas vendas pode ser ainda mais acentuado. Famílias em férias, por exemplo, podem aumentar o consumo de açaí e sorvete, especialmente em Cabo Frio que é região turística e de praia.

# %% [markdown]
# #### Os padrões e insights detectados juntamente com ações recomendadas serão escritos e explicados por completo no arquivo "relatorio_insights.pdf" localizado no GITHUB em "Parte 3 - Interpretação de Resultados"
